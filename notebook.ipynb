# %% [markdown]
# # Notebook Title - Subtitle
# ## Type of Project - Affiliation / Year
#
# ### Collaborators / Team Name
# ### Team member 1
# ### Team member 2

# %% [markdown]
# ## Project Title
#
# ### Context
# The context of the project is ...
#
# ### Data
# As part of the project, we have access to a dataset with the following features :
#
# - **Feature 1**
# - **Feature 2** (unit)
# - **Feature 3** (unit)
# - Feature category :
#     - **Feature 4** (unit)
#     - **Feature 5**
#     - ...
#
# ### Goal
# The goal of the project is to ...

# %% [markdown]
# ## Summary
#
# You can browse the notebook by clicking on the following links:
#
# - **[0. Notebook Setup](#notebook-setup)**
#
# - **[1. Exploratory phase](#exploratory-phase)**
# 	- [1.1. General Analysis of the Data](#general-analysis)
# 	- [1.2. Analysis of the Variable of Interest](#interest-variable-analysis)
#
# - **[2. Data cleaning](#data-cleaning)**
# 	- [2.1. Missing Data](#missing-data)
# 	- [2.2. Outliers](#outliers)
#
# - **[3. Preprocessing](#preprocessing)**
# 	- [3.1. Adding Features](#adding-features)
# 	- [3.2. Variable Transformation](#variable-transformation)
# 	- [3.3. Standardization](#standardization)
# 	- [3.4. Split into Training and Validation Sets](#data-split)
#
# - **[4. Model Creation](#model-creation)**
# 	- [4.1. Model 1](#model-1)
# 	- [4.2. Model 2](#model-2)
# 	- [4.3. Model 3](#model-3)
# 	- [4.4. Model 4](#model-4) - chosen model !
# 		- [4.4.1. Architecture](#architecture)
# 		- [4.4.2. Initial Hyperparameter Choice](#hp-choice)
# 		- [4.4.3. Training and Validation](#training-and-validation)
# 		- [4.4.4. Hyperparameter Optimization](#hp-optimization)
# 		- [4.4.5. Training the Test Model](#training-final-model)
#
# - **[5. Test Predictions](#test-predictions)**
#
# - **[6. Result analysis](#result-analysis)**
# 	- [6.1. Analysis of Training Predictions](#training-analysis)
# 	- [6.2. Analysis of Test Predictions](#test-analysis)
# 	- [6.3. Discussion](#discussion)
#
# - **[7. Conclusion](#conclusion)**

# %% [markdown]
# <a name="notebook-setup"></a>
# # 0. Notebook Setup
#
# In this section, we import the utilities needed to run the code contained in the Jupyter Notebook. We also define some constants and other boilerplate code.

# %%
import os
import numpy as np
import pandas as pd

# %%
TRAIN_PATH = 'train_dataset.csv'
TEST_PATH = 'test_features.csv'

if os.path.exists(TRAIN_PATH) and os.path.exists(TEST_PATH):
    train_df = pd.read_csv(TRAIN_PATH)
    test_df = pd.read_csv(TEST_PATH)

# %%
train_df.dtypes

# %%
train_df.sample(5)

# %% [markdown]
# <a name="exploratory-phase"></a>
# # 1. Exploratory Phase
#
# <a name="general-analysis"></a>
# ## 1.1. General Analysis of the Data
#
# In order to better understand the distributions of the different features and attempt to identify relationships between them, we will begin the project by analyzing the provided data.

# %% [markdown]
# <a name="variable-of-interest-analysis"></a>
# ## 1.2. Analysis of the Variable of Interest
#
# It would also be relevant to explore the variable of interest in more depth. We will verify whether certain features could explain the majority of [target variable].
#
# Let's start with the most correlated explanatory variable, [most correlated explanatory variable] as a function of [target variable]:

# %% [markdown]
# <a name="data-cleaning"></a>
# # 2. Data Cleaning
#
# Before continuing with preprocessing and training, we will check if there is any missing or outlier data.
#
# <a name="missing-data"></a>
# ## 2.1. Missing Data

# %% [markdown]
# <a name="outliers"></a>
# ## 2.2. Outliers

# %% [markdown]
# <a name="preprocessing"></a>
# # 3. Preprocessing
#
# Now that the data is all cleaned up, we can proceed to preprocessing. This step involves adding features, transforming certain variables to make them more useful, and standardizing and normalizing the data.

# %% [markdown]
# <a name="adding-features"></a>
# ## 3.1. Adding Features

# %% [markdown]
# <a name="variable-transformation"></a>
# ## 3.2. Variable Transformation

# %% [markdown]
# <a name="standardization"></a>
# ## 3.3. Standardization
#
# Since the explanatory variables have different scales, we will standardize them to make them more comparable. This approach also helps mitigate bias in some variables.

# %% [markdown]
# <a name="data-split"></a>
# ## 3.4. Split into Training and Validation Sets

# %% [markdown]
# <a name="model-creation"></a>
# # 4. Model Creation
#
# The data is now ready to be provided as input to supervised learning models. In this section, we will cover several models we implemented for prediction. We will discuss the results and compare the models in the next sections of this notebook.
#
# The models we trained are :
#
# 1. Model 1
# 2. Model 2
# 3. Model 3
# 4. Model 4 (our best model)
#
# *Note: Some models take slightly different data formats as input, and some models perform better with transformed variables. Therefore, for some models in this notebook we may need to preprocess the `train_df` data again. We mention this when this is the case.*

# %% [markdown]
# <a name="model-1"></a>
# ## 4.1. Model 1

# %% [markdown]
# <a name="model-2"></a>
# ## 4.2. Model 2

# %% [markdown]
# <a name="model-3"></a>
# ## 4.3. Model 3

# %% [markdown]
# <a name="model-4"></a>
# ## 4.4. Model 4

# %% [markdown]
# <a name="architecture"></a>
# ### 4.4.1. Architecture

# %% [markdown]
# <a name="hp-choice"></a>
# ### 4.4.2. Initial Hyperparameter Choice

# %% [markdown]
# <a name="training-and-validation"></a>
# ### 4.4.3. Training and Validation

# %% [markdown]
# <a name="hp-optimization"></a>
# ### 4.4.4. Hyperparameter Optimization

# %% [markdown]
# <a name="test-model"></a>
# ### 4.5.5. Training the Test Model
#
# Now that the hyperparameters have been optimized to improve the performance of our model, we can retrain it on the entire data set provided to avoid wasting information. This final model allows us to make true predictions of reality:

# %% [markdown]
# <a name="test-predictions"></a>
# # 5. Predictions on the Test Dataset

# %% [markdown]
# <a name="results"></a>
# # 6. Results

# %% [markdown]
# <a name="training-analysis"></a>
# ## 6.1. Analysis of Training Predictions

# %% [markdown]
# <a name="test-analysis"></a>
# ## 6.2. Analysis of Test Predictions

# %% [markdown]
# <a name="discussion"></a>
# ## 6.3. Discussion

# %% [markdown]
# <a name="conclusion"></a>
# # 7. Conclusion
